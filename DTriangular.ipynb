# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisManuelCatzoliSoriano/Simulacion-I/blob/main/DTriangular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
import numpy as np
import matplotlib.pyplot as plt

# %%
def triangular(n):
    lis=[]
    for i in range(n):
        u=r.random()
        if 0<=u<0.5:
           x=np.sqrt(2*u)
           lis.append(x)
        else:
            x=2-np.sqrt(2*(1-u))
            lis.append(x)
    return lis

# %%
R=triangular(1000)

# %%
plt.hist(R)
# Out:
# (array([ 20.,  57., 108., 126., 152., 164., 134., 131.,  80.,  28.]),
#  array([0.00882554, 0.19957021, 0.39031489, 0.58105957, 0.77180424,
#         0.96254892, 1.15329359, 1.34403827, 1.53478294, 1.72552762,
#         1.9162723 ]),
#  <BarContainer object of 10 artists>)

# %%
def cdf(M):
    n=len(M)
    x=np.sort(M)
    y=np.arange(0,n)/n
    return x,y

# %%
x_math,y_math=cdf(R)

# %%
media=np.mean(R)

# %%
plt.step(x_math, y_math)
plt.axhline(y=0.5, color='red')
plt.axvline(x=media, color='green')
